# %% [markdown]
# # Japan Fuel & Power Market Dashboard - Exploratory Analysis
#
# Starter notebook for inspecting sample historical prices, spreads, volatility regimes, and forward curves.

# %%
import pandas as pd
hist = pd.read_csv('../data/sample_historical_prices.csv', parse_dates=['date'])
curves = pd.read_csv('../data/sample_forward_curves.csv', parse_dates=['curve_date', 'contract_month'])
hist.head(), curves.head()
